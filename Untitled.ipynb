# %%
from model_fit import accuracy_evaluation
model_file = '/home/xuemeng/work_xuemeng/trend-with-uncertainty/model/model_rf.soc_ccc_v20250301.joblib'
tgt = 'soc_log1p'
import pandas as pd
train = pd.read_parquet('/home/xuemeng/work_xuemeng/trend-with-uncertainty/material/data_train_v20250301.pq')
test = pd.read_parquet('/home/xuemeng/work_xuemeng/trend-with-uncertainty/material/data_test_v20250301.pq')

# strata_col = ['time']
# group_strategy = ['logo'] # leave one group out

# maccuracy_evaluation(model_file, tgt, train, test, strata_col, group_strategy, output_folder='/home/xuemeng/work_xuemeng/trend-with-uncertainty/tmp/')

# %%
from model_fit import uncertainty_evaluation

uncertainty_evaluation(model_file, train, test, tgt, output_folder='/home/xuemeng/work_xuemeng/trend-with-uncertainty/tmp/')
