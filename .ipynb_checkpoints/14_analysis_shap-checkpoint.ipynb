# %%
version = 'v20250521'

# %% [markdown]
# ## analyze possible change drivors using SHAP values
#
# Shapley values were used to interpret covariate influence on predictions. This model-agnostic method quantifies each feature’s contribution, captures both local and global patterns, and enables intuitive visualizations.
#
# Using Python’s shap package, we computed Shapley values on the test set to produce a global summary of average absolute Shapley values for overall feature importance, and annual Shapley value plots that illustrate how individual features influenced predictions.
#
# ### state-first
#
# This is done on $c$ predictions from the same time series.

# %%
import pandas as pd
from sklearn.model_selection import GroupKFold,cross_val_predict
from skmap.misc import find_files, GoogleSheet, ttprint
import joblib
import numpy as np
import shap

prop = 'soc'
tgt = 'soc_log1p'


covs = pd.read_csv(f'./metric/feature_selected_soc_{version}.txt', header=None)[0].tolist() 
model = joblib.load(f'./model/model_rf.soc_ccc_{version}.joblib')
model.n_jobs = 90

train = pd.read_parquet(f'./material/pnt_train_{version}.pq')
train = train.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
test = pd.read_parquet(f'./metric/point_predicted_{version}.pq')
test = test.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
test['snr'] = test['soc']/test['pred_std']
print(test.shape)

model.fit(train[covs], train[tgt])
# Out:
# (5400, 424)
# RandomForestRegressor(max_depth=30, max_features=0.3, min_samples_split=5,
#                       n_estimators=64, n_jobs=90)

# %%
# rename
names = pd.read_csv(f'./metric/feature.name_selected_soc_{version}.txt', header=None)[0].tolist() 
name_map = dict(zip(covs,names))
rev_map = dict(zip(names,covs))

# get the series with 3 points SNR larger than 1
test = test.loc[test['snr']>1]
print(test.shape)
valid_ids = test['id'].value_counts()
valid_ids = valid_ids[valid_ids == 3].index
test = test[test['id'].isin(valid_ids)]
print(test.shape)
# Out:
# (2909, 424)
# (2127, 424)

# %%
import random
num = random.randint(0, len(test['id'].unique())-1)
iid = test['id'].unique()[num]
pts = test.loc[test['id']==iid]

# %%
iid
# Out:
# '34482120'

# %%
pts[['time','soc','pred','lc_survey','nuts0']]
# Out:
#       time   soc       pred  lc_survey nuts0
# 1368  2009  13.1  11.327690   cropland    ES
# 2220  2015  19.5  13.086047   cropland    ES
# 3989  2018  14.8  10.642195  grassland    ES

# %%
# calculate
ttprint('start calculating shap values')
# explainer = shap.TreeExplainer(model)
# shaps = explainer(test[covs])

explainer = shap.Explainer(model)
shaps = explainer(pts[covs])

ttprint('finish calculating shap values')

print('expected value: ',explainer.expected_value)
print('which is: ', np.expm1(explainer.expected_value[0]))
# Out:
# [14:18:15] start calculating shap values
# [14:18:20] finish calculating shap values
# expected value:  [3.21950785]
# which is:  24.01580571386546

# %%
def plot_shap_figure(idx, covs, names, shaps, scaled, title):
    filtered_features = [covs[i] for i in idx]
    filtered_names = [names[i] for i in idx]
    filtered_names = [n[:-7] if n.endswith('_annual') else n for n in filtered_names]
    filtered_shaps = shaps.values[:, idx]
    filtered_scaled = scaled.iloc[:, idx].values

    mean_abs_shap = np.abs(filtered_shaps).mean(axis=0)

    order = np.argsort(-mean_abs_shap)
    filtered_names = [filtered_names[i] for i in order]
    filtered_shaps = filtered_shaps[:, order]
    filtered_scaled = filtered_scaled[:, order]
    mean_abs_shap = mean_abs_shap[order]

    fig = plt.figure(figsize=(7, 7))
    gs = gridspec.GridSpec(nrows=3, ncols=2, width_ratios=[20, 1], height_ratios=[1, 2, 2], wspace=0.05, hspace=0.3)

    # Bar plot
    ax0 = fig.add_subplot(gs[0, 0])
    ax0.bar(np.arange(len(filtered_names)) + 0.5, mean_abs_shap, color='gray', width=1.0, edgecolor='white', linewidth=0.8)
    ax0.set_xlim(0, len(filtered_names))
    ax0.set_ylim(0,0.16)
    ax0.set_xticks(np.arange(0.5, len(filtered_names) + 0.5))
    ax0.set_xticklabels(filtered_names)
    ax0.set_ylabel("Mean |SHAP|",fontsize=12)
    ax0.set_title(title,fontsize=13)
    ax0.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
    ax0.tick_params(axis='y', labelsize=12)

    # SHAP heatmap
    ax1 = fig.add_subplot(gs[1, 0])
    shapmap = sns.heatmap(filtered_shaps, ax=ax1, cmap='coolwarm',
                          cbar_ax=fig.add_subplot(gs[1, 1]),
                          xticklabels=False, yticklabels=['2009', '2015', '2018'],
                          vmin=-0.15, vmax=0.15,
                          linewidths=0.5, linecolor='white')
    ax1.set_ylabel("SHAP values",fontsize=12)
    ax1.tick_params(axis='y', labelsize=12)
    cbar = shapmap.collections[0].colorbar
    cbar.ax.tick_params(labelsize=10)
    cbar.ax.set_aspect(30)  

    # Input heatmap
    ax2 = fig.add_subplot(gs[2, 0])
    inputmap = sns.heatmap(filtered_scaled, ax=ax2, cmap='Greens',
                           cbar_ax=fig.add_subplot(gs[2, 1]), 
                           xticklabels=filtered_names, yticklabels=['2009', '2015', '2018'],
                           linewidths=0.5, linecolor='white')
    ax2.set_ylabel("Scaled feature",fontsize=12)
    # ax2.set_xlabel("Feature")
    ax2.tick_params(axis='x', rotation=90, labelsize=12)
    ax2.tick_params(axis='y', labelsize=12)
    cbar = inputmap.collections[0].colorbar
    cbar.ax.tick_params(labelsize=10)
    cbar.ax.set_aspect(10)  
    for label in ax2.get_xticklabels():
        label.set_ha('center')
 
    plt.savefig(f'./figure/plot_shap_{title}.svg', bbox_inches='tight')
    plt.show()

# %% [markdown]
# The model responds readily to different input features, as reflected by differing Shapley values—even though the three- to six-year intervals between sampling years are relatively short for SOC to meaningfully respond to environmental changes.

# %%
annual_idx = [i for i, name in enumerate(names) if "_annual" in name]
non_annual_idx = [i for i, name in enumerate(names) if "_annual" not in name]

plot_shap_figure(annual_idx, covs, names, shaps, scaled, 'Dynamic')
plot_shap_figure(non_annual_idx, covs, names, shaps, scaled, "Static")

# %% [markdown]
# #### Plot description:
#
# Shapley analysis of SOC time series predictions using the $c$-model. Static and dynamic features are displayed in the left and right panels, respectively. The top panel shows the mean absolute Shapley values for each feature, the middle panel displays the yearly Shapley values contributing to the predictions, and the bottom panel shows the corresponding feature values scaled between 0 and 1. The example is a randomly selected LUCAS time series (ID: 34482120), representing a cropland site in Spain.
#
# #### Results description and interpretation
# This presents the Shapley values of individual features used to predict c for the same time series in the years 2009, 2015, and 2018.
#
# Static features—such as soil texture or topography—exhibit higher mean absolute Shapley values, indicating greater overall importance in model predictions. This suggests that the model is primarily driven by spatially invariant factors, meaning that subtle temporal changes are likely overshadowed by stronger spatial patterns.
#
# In terms of interpretation, negative Shapley values indicate that a feature contributes to lowering the prediction relative to the baseline (typically the mean target value), while positive values indicate an upward influence. The absolute magnitude reflects the strength of the contribution. Although most static features remain constant across years, small differences in values—and consequently in Shapley values—can occur due to slight shifts in sampling location.
#
# Even for features with identical values across years, some variation in Shapley values is observed. Dynamic features, in contrast, exhibit greater temporal variation in both their input values and their associated Shapley values.

# %% [markdown]
# ### change-first
# - pair, $\delta$

# %%
version = 'v20250521'

import pandas as pd
from sklearn.model_selection import GroupKFold,cross_val_predict
from skmap.misc import find_files, GoogleSheet, ttprint
import joblib
import numpy as np

# params
prop = 'change'
tgt = 'soc_change'
space = 'normal'

covs = pd.read_csv(f'./metric/feature_selected_{prop}_{version}.txt', header=None)[0].tolist() 
names = pd.read_csv(f'./metric/feature.name_selected_{prop}_{version}.txt', header=None)[0].tolist() 
name_map = dict(zip(covs,names))
rev_map = dict(zip(names,covs))

model = joblib.load(f'./model/model_rf.{prop}_ccc_{version}.joblib')
model.n_jobs = 90

train = pd.read_parquet(f'./material/pair_train_{version}.pq')
train = train.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
test = pd.read_parquet(f'./material/pair_test_{version}.pq')
test = test.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
X_test = test[covs].copy()
X_test_ren = X_test.rename(columns=name_map)

model.fit(train[covs], train[tgt])

import shap

explainer = shap.Explainer(model)

import matplotlib.pyplot as plt

explainer = explainer = shap.Explainer(model)
print('expected value: ',explainer.expected_value)

ttprint('start calculating shap values')
shap_values = explainer(X_test_ren)     
ttprint('finish calculating shap values')
# Out:
# expected value:  [1.82548042]
# [12:30:04] start calculating shap values
# [12:30:12] finish calculating shap values

# %%
# global SHAP mean
plt.figure(figsize=(6,4))
shap.plots.bar(shap_values, max_display=20, show=False)
plt.title("Mean |SHAP| (global importance)")
plt.tight_layout()
plt.show()

# %%
K = 3
mean_abs = np.abs(shap_values.values).mean(axis=0)
top_idx = np.argsort(-mean_abs)[:K]
top_feats = [shap_values.feature_names[i] for i in top_idx]
for f in top_feats:
    plt.figure(figsize=(6,5))
    shap.plots.scatter(shap_values[:, f], show=False)
    plt.title(f"SHAP dependence: {f}")
    plt.tight_layout(); plt.show()

# %% [markdown]
# #### result description
#
# The most influential predictors identified by the SHAP analysis were soil moisture in the third quarter (static in the current dataset, i.e., one value across all years), followed by the standard deviation of precipitation and the trend of the Normalized Difference Tillage Index (NDTI) prior to the modelled change period.
#
# Partial dependence plots for the top predictors did not reveal consistent or interpretable relationships with the modelled SOC change.
#
# ### change-first, $\beta$

# %%
version = 'v20250521'

import pandas as pd
from sklearn.model_selection import GroupKFold,cross_val_predict
from skmap.misc import find_files, GoogleSheet, ttprint
import joblib
import numpy as np

# params
prop = 'slope'
tgt = 'ts_slope'
space = 'normal'

covs = pd.read_csv(f'./metric/feature_selected_slope_{version}.txt', header=None)[0].tolist() 
names = pd.read_csv(f'./metric/feature.name_selected_slope_{version}.txt', header=None)[0].tolist() 
name_map = dict(zip(covs,names))
rev_map = dict(zip(names,covs))

model = joblib.load(f'./model/model_rf.{prop}_ccc_{version}.joblib')
model.n_jobs = 90

train = pd.read_parquet(f'./material/srs_train_{version}.pq')
train = train.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
test = pd.read_parquet(f'./material/srs_test_{version}.pq')
test = test.dropna(subset=covs+[tgt],how='any').reset_index(drop=True)
X_test = test[covs].copy()
X_test_ren = X_test.rename(columns=name_map)

model.fit(train[covs], train[tgt])

import shap

explainer = shap.Explainer(model)

import matplotlib.pyplot as plt

explainer = explainer = shap.Explainer(model)
print('expected value: ',explainer.expected_value)

ttprint('start calculating shap values')
shap_values = explainer(X_test_ren)     
ttprint('finish calculating shap values')
# Out:
# expected value:  [0.26946384]
# [13:03:10] start calculating shap values
# [13:04:08] finish calculating shap values

# %%
# global SHAP mean
plt.figure(figsize=(6,4))
shap.plots.bar(shap_values, max_display=10, show=False)
plt.title("Mean |SHAP| (global importance)")
plt.tight_layout()
plt.show()

K = 5
mean_abs = np.abs(shap_values.values).mean(axis=0)
top_idx = np.argsort(-mean_abs)[:K]
top_feats = [shap_values.feature_names[i] for i in top_idx]
for f in top_feats:
    plt.figure(figsize=(6,5))
    shap.plots.scatter(shap_values[:, f], show=False)
    plt.title(f"SHAP dependence: {f}")
    plt.tight_layout(); plt.show()

# %% [markdown]
# ### Results interpretation
#
# Compared to the $\delta$ model, three CHELSA bioclimatic variables surpassed soil moisture in importance, becoming the most influential predictors. However, these variables are static in our dataset. While the partial dependence plots reveal somewhat clearer patterns than those observed in the $\delta$ modelling, these relationships are conditional on the specific dataset used and should be interpreted with caution. Given the low predictive accuracy and low signal-to-noise ratio of the model, these patterns likely reflect model behavior rather than robust environmental controls.
